# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "../output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 626

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
lat = []
lng = []
max_temp = []
humidity = []
clouds = []
wind = []
country = []
date = []
city_name = []

print("Beginning Data Retrieval")
print("-----------------------------")
chunk_size = 50
set_index = 0

# Append information   
# Building URL
url="http://api.openweathermap.org/data/2.5/weather?"
query_url = f"{url}appid={weather_api_key}&q="
# iterate over city list in chuck size of 50
for start in range(0,len(cities),chunk_size): 
    end = start + chunk_size
    set_index += 1
    for city in cities[start:end]:
        response = requests.get(query_url + city).json()
        
        try:
            city_name.append(response['name'])
            lat.append(response['coord']['lat'])
            lng.append (response["coord"]["lon"])
            max_temp.append(response["main"]["temp_max"])
            humidity.append(response["main"]["humidity"])
            clouds.append(response["clouds"]["all"])
            wind.append(response["wind"]["speed"])
            country.append(response["sys"]["country"])
            date.append(response["dt"])    
            print(f"Processing Record {cities[start:end].index(city)+1} of Set {set_index} | {city}")
        except:
            print("City not found. Skipping...")
            pass

print("-----------------------------")
print("Data Retrieval Complete")      
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hermanus
# Processing Record 2 of Set 1 | cidreira
# Processing Record 3 of Set 1 | mataura
# Processing Record 4 of Set 1 | buraydah
# Processing Record 5 of Set 1 | nikolskoye
# Processing Record 6 of Set 1 | kodiak
# Processing Record 7 of Set 1 | vaini
# Processing Record 8 of Set 1 | albanel
# Processing Record 9 of Set 1 | san pedro de macoris
# Processing Record 10 of Set 1 | castro
# Processing Record 11 of Set 1 | nanortalik
# Processing Record 12 of Set 1 | bluff
# Processing Record 13 of Set 1 | mahebourg
# Processing Record 14 of Set 1 | lattes
# Processing Record 15 of Set 1 | oeiras do para
# City not found. Skipping...
# Processing Record 17 of Set 1 | souillac
# Processing Record 18 of Set 1 | cape town
# Processing Record 19 of Set 1 | mar del plata
# Processing Record 20 of Set 1 | pacific grove
# Processing Record 21 of Set 1 | dingle
# Processing Record 22 of Set 1 | avarua
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 25 of Set 1 | teguldet
# Processing Record 26 of Set 1 | bosaso
# Processing Record 27 of Set 1 | los llanos de aridane
# Processing Record 28 of Set 1 | northview
# Processing Record 29 of Set 1 | mecca
# Processing Record 30 of Set 1 | margate
# Processing Record 31 of Set 1 | leningradskiy
# Processing Record 32 of Set 1 | yeppoon
# Processing Record 33 of Set 1 | busselton
# City not found. Skipping...
# Processing Record 35 of Set 1 | hambantota
# Processing Record 36 of Set 1 | mitsamiouli
# Processing Record 37 of Set 1 | tazovskiy
# Processing Record 38 of Set 1 | pevek
# City not found. Skipping...
# Processing Record 40 of Set 1 | burriana
# Processing Record 41 of Set 1 | mehamn
# Processing Record 42 of Set 1 | rikitea
# Processing Record 43 of Set 1 | norman wells
# Processing Record 44 of Set 1 | riverton
# Processing Record 45 of Set 1 | camacha
# Processing Record 46 of Set 1 | usinsk
# Processing Record 47 of Set 1 | codrington
# Processing Record 48 of Set 1 | bambous virieux
# Processing Record 49 of Set 1 | merauke
# Processing Record 50 of Set 1 | bredasdorp
# Processing Record 1 of Set 2 | provideniya
# Processing Record 2 of Set 2 | ahipara
# Processing Record 3 of Set 2 | tiksi
# Processing Record 4 of Set 2 | boa vista
# Processing Record 5 of Set 2 | petropavlovskoye
# City not found. Skipping...
# Processing Record 7 of Set 2 | port lincoln
# Processing Record 13 of Set 5 | severo-kurilsk
# Processing Record 14 of Set 5 | blagoyevo
# Processing Record 15 of Set 5 | pizarro
# Processing Record 16 of Set 5 | acajutla
# Processing Record 17 of Set 5 | dolores
# Processing Record 18 of Set 5 | yenagoa
# Processing Record 19 of Set 5 | kulunda
# City not found. Skipping...
# Processing Record 21 of Set 5 | fairview
# Processing Record 22 of Set 5 | butaritari
# Processing Record 23 of Set 5 | victoria
# Processing Record 24 of Set 5 | katsuura
# Processing Record 25 of Set 5 | port alfred
# Processing Record 26 of Set 5 | esperance
# Processing Record 27 of Set 5 | daund
# Processing Record 28 of Set 5 | sorland
# Processing Record 29 of Set 5 | cerfontaine
# Processing Record 30 of Set 5 | koscierzyna
# Processing Record 31 of Set 5 | kisangani
# City not found. Skipping...
# Processing Record 33 of Set 5 | chuy
# Processing Record 34 of Set 5 | bilibino
# Processing Record 35 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 36 of Set 5 | zhigansk
# Processing Record 37 of Set 5 | billings
# Processing Record 38 of Set 5 | maiduguri
# Processing Record 39 of Set 5 | chimoio
# Processing Record 40 of Set 5 | caravelas
# Processing Record 41 of Set 5 | new norfolk
# Processing Record 42 of Set 5 | fukue
# Processing Record 43 of Set 5 | seybaplaya
# Processing Record 44 of Set 5 | vanimo
# Processing Record 45 of Set 5 | simplicio mendes
# Processing Record 46 of Set 5 | sangar
# Processing Record 47 of Set 5 | salalah
# Processing Record 48 of Set 5 | kaitangata
# City not found. Skipping...
# Processing Record 50 of Set 5 | bud
# Processing Record 1 of Set 6 | avera
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 4 of Set 6 | longyearbyen
# Processing Record 5 of Set 6 | saint-augustin
# City not found. Skipping...
# Processing Record 7 of Set 6 | soyo
# Processing Record 8 of Set 6 | san luis
# Processing Record 9 of Set 6 | qasigiannguit
# Processing Record 10 of Set 6 | tasiilaq
# Processing Record 11 of Set 6 | aksu
# Processing Record 12 of Set 6 | oro valley
# Processing Record 13 of Set 6 | saurimo
# Processing Record 14 of Set 6 | strezhevoy
# Processing Record 15 of Set 6 | lake city
# Processing Record 16 of Set 6 | honiara
# Processing Record 17 of Set 6 | harbour breton
# Processing Record 18 of Set 6 | lata
# Processing Record 19 of Set 6 | puerto escondido
# Processing Record 20 of Set 6 | saint-francois
# Processing Record 21 of Set 6 | san cristobal
# Processing Record 22 of Set 6 | magdeburg
# Processing Record 23 of Set 6 | fortuna
# Processing Record 24 of Set 6 | tondano
# Processing Record 25 of Set 6 | iskilip
# City not found. Skipping...
# Processing Record 27 of Set 6 | pangnirtung
# Processing Record 28 of Set 6 | trairi
# Processing Record 29 of Set 6 | langres
# Processing Record 30 of Set 6 | naze
# Processing Record 31 of Set 6 | alice springs
# Processing Record 32 of Set 6 | brae
# Processing Record 33 of Set 6 | naryan-mar
# Processing Record 34 of Set 6 | skibbereen
# Processing Record 35 of Set 6 | jimenez
# City not found. Skipping...
# Processing Record 37 of Set 6 | haflong
# Processing Record 38 of Set 6 | kralendijk
# Processing Record 39 of Set 6 | natal
# Processing Record 40 of Set 6 | tuni
# Processing Record 41 of Set 6 | nurota
# Processing Record 42 of Set 6 | mutis
# Processing Record 43 of Set 6 | guerrero negro
# Processing Record 44 of Set 6 | rochester
# Processing Record 45 of Set 6 | srivardhan
# Processing Record 46 of Set 6 | vao
# Processing Record 47 of Set 6 | faanui
# Processing Record 48 of Set 6 | chengde
# Processing Record 49 of Set 6 | airai
# Processing Record 50 of Set 6 | oranjemund
# City not found. Skipping...
# Processing Record 2 of Set 7 | colares
# Processing Record 3 of Set 7 | enshi
# Processing Record 4 of Set 7 | opportunity
# Processing Record 5 of Set 7 | manado
# Processing Record 6 of Set 7 | rassvet
# Processing Record 7 of Set 7 | naberera
# Processing Record 8 of Set 7 | cabo san lucas
# Processing Record 9 of Set 7 | erenhot
# Processing Record 10 of Set 7 | kenai
# Processing Record 11 of Set 7 | simav
# Processing Record 12 of Set 7 | ravenna
# Processing Record 13 of Set 7 | piedras negras
# City not found. Skipping...
# Processing Record 15 of Set 7 | alugan
# Processing Record 16 of Set 7 | pa sang
# Processing Record 17 of Set 7 | uspenka
# Processing Record 18 of Set 7 | hollins
# Processing Record 19 of Set 7 | cayenne
# City not found. Skipping...
# Processing Record 21 of Set 7 | rafraf
# Processing Record 22 of Set 7 | jiuquan
# Processing Record 23 of Set 7 | rio rancho
# City not found. Skipping...
# Processing Record 25 of Set 7 | thinadhoo
# Processing Record 26 of Set 7 | ponot
# Processing Record 27 of Set 7 | liwale
# Processing Record 28 of Set 7 | sola
# City not found. Skipping...
# Processing Record 30 of Set 7 | kargil
# Processing Record 31 of Set 7 | ler
# Processing Record 32 of Set 7 | lagunillas
# Processing Record 33 of Set 7 | north bend
# City not found. Skipping...
# Processing Record 35 of Set 7 | kampene
# Processing Record 36 of Set 7 | vilhena
# Processing Record 37 of Set 7 | macomb
# Processing Record 38 of Set 7 | semey
# Processing Record 39 of Set 7 | maniwaki
# Processing Record 40 of Set 7 | bida
# Processing Record 41 of Set 7 | rio grande
# Processing Record 42 of Set 7 | severo-yeniseyskiy
# Processing Record 43 of Set 7 | dali
# City not found. Skipping...
# Processing Record 45 of Set 7 | morris
# Processing Record 46 of Set 7 | maryville
# Processing Record 47 of Set 7 | yulara
# Processing Record 48 of Set 7 | necochea
# Processing Record 49 of Set 7 | santiago del estero
# City not found. Skipping...
# Processing Record 1 of Set 8 | plettenberg bay
# Processing Record 2 of Set 8 | marysville
# Processing Record 3 of Set 8 | midland
# Processing Record 4 of Set 8 | cassilandia
# Processing Record 5 of Set 8 | tocache
# Processing Record 6 of Set 8 | grand bank
# Processing Record 7 of Set 8 | aykhal
# Processing Record 8 of Set 8 | innisfail
# Processing Record 9 of Set 8 | tevaitoa
# Processing Record 10 of Set 8 | sibu
# Processing Record 11 of Set 8 | yhu
# Processing Record 12 of Set 8 | hasaki
# Processing Record 13 of Set 8 | kushima
# Processing Record 14 of Set 8 | negombo
# Processing Record 15 of Set 8 | hirado
# Processing Record 16 of Set 8 | klaksvik
# Processing Record 17 of Set 8 | cap malheureux
# Processing Record 43 of Set 9 | san ramon
# Processing Record 44 of Set 9 | teahupoo
# Processing Record 45 of Set 9 | altensteig
# Processing Record 46 of Set 9 | narsaq
# Processing Record 47 of Set 9 | havelock
# Processing Record 48 of Set 9 | seoul
# Processing Record 49 of Set 9 | mufulira
# Processing Record 50 of Set 9 | yumen
# Processing Record 1 of Set 10 | emba
# Processing Record 2 of Set 10 | la romana
# Processing Record 3 of Set 10 | vila velha
# City not found. Skipping...
# Processing Record 5 of Set 10 | shimanovsk
# Processing Record 6 of Set 10 | nampula
# Processing Record 7 of Set 10 | komsomolskiy
# Processing Record 8 of Set 10 | adeje
# Processing Record 9 of Set 10 | morelia
# City not found. Skipping...
# Processing Record 11 of Set 10 | berlevag
# Processing Record 12 of Set 10 | yarmouth
# Processing Record 13 of Set 10 | phan thiet
# Processing Record 14 of Set 10 | poya
# Processing Record 15 of Set 10 | lensk
# Processing Record 16 of Set 10 | bloemfontein
# City not found. Skipping...
# Processing Record 18 of Set 10 | omsukchan
# Processing Record 19 of Set 10 | porto novo
# Processing Record 20 of Set 10 | mayumba
# Processing Record 21 of Set 10 | inuvik
# Processing Record 22 of Set 10 | mae sot
# Processing Record 23 of Set 10 | khlevnoye
# Processing Record 24 of Set 10 | pemba
# Processing Record 25 of Set 10 | zmeinogorsk
# Processing Record 26 of Set 10 | pechenga
# Processing Record 27 of Set 10 | severobaykalsk
# City not found. Skipping...
# Processing Record 29 of Set 10 | usogorsk
# Processing Record 30 of Set 10 | flinders
# Processing Record 31 of Set 10 | dubbo
# Processing Record 32 of Set 10 | general roca
# Processing Record 33 of Set 10 | mayo
# Processing Record 34 of Set 10 | rugby
# Processing Record 35 of Set 10 | mazatlan
# Processing Record 36 of Set 10 | christchurch
# Processing Record 37 of Set 10 | severodvinsk
# Processing Record 38 of Set 10 | port hardy
# Processing Record 39 of Set 10 | hays
# Processing Record 40 of Set 10 | georgiyevskoye
# Processing Record 41 of Set 10 | husavik
# Processing Record 42 of Set 10 | lokosovo
# Processing Record 43 of Set 10 | koutiala
# Processing Record 44 of Set 10 | chernyshevskiy
# Processing Record 45 of Set 10 | owatonna
# Processing Record 46 of Set 10 | tura
# Processing Record 47 of Set 10 | banjar
# Processing Record 48 of Set 10 | colac
# Processing Record 49 of Set 10 | imperial
# Processing Record 50 of Set 10 | uvalde
# Processing Record 1 of Set 11 | arenillas
# Processing Record 2 of Set 11 | wajid
# Processing Record 3 of Set 11 | jamui
# Processing Record 4 of Set 11 | birin
# Processing Record 5 of Set 11 | rameswaram
# Processing Record 6 of Set 11 | sorgun
# Processing Record 7 of Set 11 | trinidad
# Processing Record 8 of Set 11 | dunedin
# Processing Record 9 of Set 11 | fuxin
# Processing Record 10 of Set 11 | ilulissat
# Processing Record 11 of Set 11 | batagay
# Processing Record 12 of Set 11 | bowen
# Processing Record 13 of Set 11 | lavrentiya
# Processing Record 14 of Set 11 | saldanha
# Processing Record 15 of Set 11 | tromso
# Processing Record 16 of Set 11 | mana
# Processing Record 17 of Set 11 | port antonio
# Processing Record 18 of Set 11 | zhangye
# City not found. Skipping...
# Processing Record 20 of Set 11 | pauini
# Processing Record 21 of Set 11 | moussoro
# Processing Record 22 of Set 11 | rio gallegos
# Processing Record 23 of Set 11 | springbok
# Processing Record 24 of Set 11 | paramonga
# Processing Record 25 of Set 11 | auki
# Processing Record 26 of Set 11 | wundanyi
# Processing Record 27 of Set 11 | gushikawa
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 30 of Set 11 | ahuimanu
# Processing Record 31 of Set 11 | coromandel
# Processing Record 32 of Set 11 | kismayo
# Processing Record 33 of Set 11 | karratha
# Processing Record 34 of Set 11 | mae sai
# Processing Record 35 of Set 11 | adrar
# Processing Record 36 of Set 11 | keti bandar
# City not found. Skipping...
# Processing Record 38 of Set 11 | oudtshoorn
# Processing Record 39 of Set 11 | kinsale
# Processing Record 40 of Set 11 | sambava
# Processing Record 41 of Set 11 | puerto leguizamo
# Processing Record 42 of Set 11 | lompoc
# Processing Record 43 of Set 11 | kaniama
# Processing Record 44 of Set 11 | abu kamal
# Processing Record 45 of Set 11 | andenes
# Processing Record 46 of Set 11 | alofi
# Processing Record 47 of Set 11 | baykit
# Processing Record 48 of Set 11 | yar-sale
# Processing Record 49 of Set 11 | tashtagol
# Processing Record 50 of Set 11 | paso de carrasco
# Processing Record 1 of Set 12 | port blair
# Processing Record 2 of Set 12 | pipar
# Processing Record 3 of Set 12 | morondava
# Processing Record 4 of Set 12 | araouane
# Processing Record 5 of Set 12 | samarai
# Processing Record 6 of Set 12 | yarumal
# Processing Record 7 of Set 12 | gweru
# Processing Record 8 of Set 12 | agirish
# Processing Record 9 of Set 12 | turiacu
# Processing Record 10 of Set 12 | kirakira
# Processing Record 11 of Set 12 | high rock
# Processing Record 12 of Set 12 | aasiaat
# Processing Record 13 of Set 12 | hovd
# Processing Record 14 of Set 12 | cockburn town
# Processing Record 15 of Set 12 | thyboron
# Processing Record 16 of Set 12 | havre-saint-pierre
# City not found. Skipping...
# Processing Record 18 of Set 12 | sayaxche
# Processing Record 19 of Set 12 | tayu
# Processing Record 20 of Set 12 | marawi
# Processing Record 21 of Set 12 | bull savanna
# Processing Record 22 of Set 12 | kutum
# Processing Record 23 of Set 12 | suntar
# Processing Record 24 of Set 12 | poum
# Processing Record 25 of Set 12 | namatanai
# Processing Record 26 of Set 12 | kavaratti
# Processing Record 27 of Set 12 | winona
# Processing Record 28 of Set 12 | stephenville
# Processing Record 29 of Set 12 | bilma
# City not found. Skipping...
# Processing Record 31 of Set 12 | kamyaran
# Processing Record 32 of Set 12 | bemidji
# Processing Record 33 of Set 12 | sayyan
# Processing Record 34 of Set 12 | zaysan
# Processing Record 35 of Set 12 | geraldton
# Processing Record 36 of Set 12 | chippewa falls
# Processing Record 37 of Set 12 | kijang
# Processing Record 38 of Set 12 | sinnamary
# Processing Record 39 of Set 12 | ranong
# Processing Record 40 of Set 12 | roma
# Processing Record 41 of Set 12 | san patricio
# Processing Record 42 of Set 12 | uyuni
# Processing Record 43 of Set 12 | kampot
# Processing Record 44 of Set 12 | quatre cocos
# Processing Record 45 of Set 12 | ekhabi
# Processing Record 46 of Set 12 | victor harbor
# Processing Record 47 of Set 12 | fontem
# Processing Record 48 of Set 12 | alto piquiri
# Processing Record 49 of Set 12 | san juan de uraba
# Processing Record 50 of Set 12 | morlaix
# Processing Record 1 of Set 13 | puri
# Processing Record 2 of Set 13 | barreirinhas
# Processing Record 3 of Set 13 | faya
# Processing Record 4 of Set 13 | the valley
# City not found. Skipping...
# Processing Record 6 of Set 13 | pontes e lacerda
# Processing Record 7 of Set 13 | ndola
# Processing Record 8 of Set 13 | mahon
# Processing Record 9 of Set 13 | mocuba
# Processing Record 10 of Set 13 | sisimiut
# Processing Record 11 of Set 13 | lima
# Processing Record 12 of Set 13 | camabatela
# Processing Record 13 of Set 13 | sakakah
# Processing Record 14 of Set 13 | chapais
# Processing Record 15 of Set 13 | rawson
# Processing Record 16 of Set 13 | ciudad bolivar
# Processing Record 17 of Set 13 | pangai
# Processing Record 18 of Set 13 | mount isa
# Processing Record 19 of Set 13 | vyazma
# Processing Record 20 of Set 13 | vostok
# Processing Record 21 of Set 13 | tallahassee
# Processing Record 22 of Set 13 | conakry
# Processing Record 23 of Set 13 | launceston
# Processing Record 24 of Set 13 | zimovniki
# Processing Record 25 of Set 13 | te anau
# Processing Record 26 of Set 13 | yuanping
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_df = pd.DataFrame({"City": city_name, "Lat": lat, "Lng": lng,
                        "Max Temp": max_temp, "Humidity": humidity, "Clouds": clouds,
                       "Wind": wind, "Country": country, "Date": date}) 
# Display the DataFrame
city_df.head()
# Out:
#          City    Lat     Lng  Max Temp  Humidity  Clouds  Wind Country  \
# 0    Hermanus -34.42   19.23    292.04        63      93  1.34      ZA
# 1    Cidreira -30.18  -50.21    296.05        58       0  2.49      BR
# 2     Mataura -46.19  168.86    277.19        95      47  0.23      NZ
# 3    Buraidah  26.33   43.98    303.15        15       0  4.10      SA
# 4  Nikolskoye  59.70   30.79    283.15        87      75  2.00      RU
#
#          Date
# 0  1602514974
# 1  1602514974
# 2  1602514974
# 3  1602514975
# 4  1602514975

# %%
# Export the city data into a .csv
city_df.to_csv("../output_data/city_weather.csv",index=False)

# %%
city_df.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity      Clouds        Wind  \
# count  573.000000  573.000000  573.000000  573.000000  573.000000  573.000000
# mean    19.298848   13.488045  291.063054   70.064572   50.849913    3.800105
# std     33.490921   90.102935   10.900780   23.150791   37.963801    2.482420
# min    -54.800000 -175.200000  260.570000    4.000000    0.000000    0.140000
# 25%     -8.190000  -66.830000  283.150000   57.000000   10.000000    2.000000
# 50%     22.290000   17.890000  293.150000   78.000000   50.000000    3.260000
# 75%     46.830000   91.640000  299.320000   88.000000   90.000000    5.100000
# max     78.220000  179.320000  313.540000  100.000000  100.000000   18.900000
#
#                Date
# count  5.730000e+02
# mean   1.602515e+09
# std    7.917926e+01
# min    1.602514e+09
# 25%    1.602515e+09
# 50%    1.602515e+09
# 75%    1.602515e+09
# max    1.602515e+09

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
# There is NO cities with humidity>100
city_df.loc[city_df.Humidity>100]
# Out:
# Empty DataFrame
# Columns: [City, Lat, Lng, Max Temp, Humidity, Clouds, Wind, Country, Date]
# Index: []

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %%
# Check Datatypes before plotting
city_df.dtypes
# Out:
# City         object
# Lat         float64
# Lng         float64
# Max Temp    float64
# Humidity      int64
# Clouds        int64
# Wind        float64
# Country      object
# Date          int64
# dtype: object

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Scatter plot of Latitude and Temperature
plt.scatter(city_df.Lat,city_df['Max Temp'],facecolor='steelblue',edgecolor='black')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title('City Latitude vs. Max Temperature (10/11/20)')
plt.grid(which='major',linewidth=1,alpha=0.7)
plt.savefig('../output_data/lat&temp.png',dpi=200)

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Scatter plot of Latitude and Humidity
plt.scatter(city_df.Lat,city_df.Humidity,facecolor='steelblue',edgecolor='black')
plt.xlabel('Latitude')
plt.ylabel('HUmidity (%)')
plt.title('City Latitude vs. Humidity (10/11/20)')
plt.grid(which='major',linewidth=1,alpha=0.7)
plt.savefig('../output_data/lat&humidity.png',dpi=200)

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Scatter plot of Latitude and Cloud
plt.scatter(city_df.Lat,city_df['Clouds'],facecolor='steelblue',edgecolor='black')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('City Latitude vs. Cloudiness (10/11/20)')
plt.grid(which='major',linewidth=1,alpha=0.7)
plt.savefig('../output_data/lat&clouds.png',dpi=200)

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Scatter plot of Latitude and Wind
plt.scatter(city_df.Lat,city_df['Wind'],facecolor='steelblue',edgecolor='black')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title('City Latitude vs. Cloudiness (10/11/20)')
plt.grid(which='major',linewidth=1,alpha=0.7)
plt.savefig('../output_data/lat&clouds.png',dpi=200)

# %% [markdown]
# ## Linear Regression

# %%
N_hemisphere = city_df.loc[city_df['Lat'] >= 0]
S_hemisphere = city_df.loc[city_df['Lat'] < 0]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Perform a linear regression on temp and lat
(slope, intercept, rvalue, pvalue, stderr) = linregress(N_hemisphere['Lat'], N_hemisphere['Max Temp'])
# Create line of best fit
fit_values = slope * N_hemisphere['Lat'] + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
# plot 
plt.scatter(N_hemisphere['Lat'],N_hemisphere['Max Temp'])
plt.plot(N_hemisphere['Lat'],fit_values,'r-',label='y={:.2f}x+{:.2f}'.format(slope,intercept))
#plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temperature')
plt.legend(fontsize=15)
plt.title('Northern Hemisphere - Max Temp vs. Latitude Linear Regression')
plt.savefig("../output_data/Fig1.png")
plt.show()

print(f"The correlation between tempurature and latitude is about {round(rvalue,2)}.")
# Out:
# The correlation between tempurature and latitude is about -0.88.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Perform a linear regression on temp and lat
(slope, intercept, rvalue, pvalue, stderr) = linregress(S_hemisphere['Lat'], S_hemisphere['Max Temp'])
# Create line of best fit
fit_values = slope * S_hemisphere['Lat'] + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
# plot 
plt.scatter(S_hemisphere['Lat'],S_hemisphere['Max Temp'])
plt.plot(S_hemisphere['Lat'],fit_values,'r-',label='y={:.2f}x+{:.2f}'.format(slope,intercept))

plt.xlabel('Latitude')
plt.ylabel('Max Temperature')
plt.legend(fontsize=15)
plt.title('Southern Hemisphere - Max Temp vs. Latitude Linear Regression')

plt.savefig("../output_data/Fig2.png",dpi=100)
plt.show()
print(f"The correlation between tempurature and latitude is about {round(rvalue,2)}.")
# Out:
# The correlation between tempurature and latitude is about 0.76.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Perform a linear regression on temp and lat
(slope, intercept, rvalue, pvalue, stderr) = linregress(N_hemisphere['Lat'], N_hemisphere['Humidity'])
# Create line of best fit
fit_values = slope * N_hemisphere['Lat'] + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
# plot 
plt.scatter(N_hemisphere['Lat'],N_hemisphere['Humidity'])
plt.plot(N_hemisphere['Lat'],fit_values,'r-',label='y={:.2f}x+{:.2f}'.format(slope,intercept))

plt.xlabel('Latitude')
plt.ylabel('Humidity(%)')
plt.legend(fontsize=15)
plt.title('Northern Hemisphere - Humidity vs. Latitude Linear Regression')

plt.savefig("../output_data/Fig3.png",dpi=100)
plt.show()
print(f"The correlation between Humidity and latitude is about {round(rvalue,2)}.")
# Out:
# The correlation between Humidity and latitude is about 0.25.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Perform a linear regression on temp and lat
(slope, intercept, rvalue, pvalue, stderr) = linregress(S_hemisphere['Lat'], S_hemisphere['Humidity'])
# Create line of best fit
fit_values = slope * S_hemisphere['Lat'] + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
# plot 
plt.scatter(S_hemisphere['Lat'],S_hemisphere['Humidity'])
plt.plot(S_hemisphere['Lat'],fit_values,'r-',label='y={:.2f}x+{:.2f}'.format(slope,intercept))
#plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.legend(fontsize=15)
plt.title('Southern Hemisphere - Humidity vs. Latitude Linear Regression')


plt.savefig("../output_data/Fig4.png",dpi=100)
plt.show()
print(f"The correlation between Humidity and latitude is about {round(rvalue,2)}.")
# Out:
# The correlation between Humidity and latitude is about 0.01.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Perform a linear regression on temp and lat
(slope, intercept, rvalue, pvalue, stderr) = linregress(N_hemisphere['Lat'], N_hemisphere['Clouds'])
# Create line of best fit
fit_values = slope * N_hemisphere['Lat'] + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
# plot 
plt.scatter(N_hemisphere['Lat'],N_hemisphere['Clouds'])
plt.plot(N_hemisphere['Lat'],fit_values,'r-',label='y={:.2f}x+{:.2f}'.format(slope,intercept))

plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%) ')
plt.legend(fontsize=15)
plt.title('Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')


plt.savefig("../output_data/Fig5.png",dpi=100)
plt.show()
print(f"The correlation between Cloudiness (%) and latitude is about {round(rvalue,2)}.")
# Out:
# The correlation between Cloudiness (%) and latitude is about 0.23.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Perform a linear regression on temp and lat
(slope, intercept, rvalue, pvalue, stderr) = linregress(S_hemisphere['Lat'], S_hemisphere['Clouds'])
# Create line of best fit
fit_values = slope * S_hemisphere['Lat'] + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
# plot 
plt.scatter(S_hemisphere['Lat'],S_hemisphere['Clouds'])
plt.plot(S_hemisphere['Lat'],fit_values,'r-',label='y={:.2f}x+{:.2f}'.format(slope,intercept))
#plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%) ')
plt.legend(fontsize=15)
plt.title('Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')

plt.savefig("../output_data/Fig6.png",dpi=100)
plt.show()
print(f"The correlation between Cloudiness (%) and latitude is about {round(rvalue,2)}.")
# Out:
# The correlation between Cloudiness (%) and latitude is about 0.1.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Perform a linear regression on temp and lat
(slope, intercept, rvalue, pvalue, stderr) = linregress(N_hemisphere['Lat'], N_hemisphere['Wind'])
# Create line of best fit
fit_values = slope * N_hemisphere['Lat'] + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
# plot 
plt.scatter(N_hemisphere['Lat'],N_hemisphere['Wind'])
plt.plot(N_hemisphere['Lat'],fit_values,'r-',label='y={:.2f}x+{:.2f}'.format(slope,intercept))

plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.legend(fontsize=15)
plt.title('Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression')

plt.savefig("../output_data/Fig7.png",dpi=100)
plt.show()
print(f"The correlation between Wind Speed (mph) and latitude is about {round(rvalue,2)}.")
# Out:
# The correlation between Wind Speed (mph) and latitude is about 0.14.

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Perform a linear regression on temp and lat
(slope, intercept, rvalue, pvalue, stderr) = linregress(S_hemisphere['Lat'], S_hemisphere['Wind'])
# Create line of best fit
fit_values = slope * S_hemisphere['Lat'] + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
# plot 
plt.scatter(S_hemisphere['Lat'],S_hemisphere['Wind'])
plt.plot(S_hemisphere['Lat'],fit_values,'r-',label='y={:.2f}x+{:.2f}'.format(slope,intercept))
#plt.annotate(line_eq,(6,10),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph) ')
plt.legend(fontsize=15)
plt.title('Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression')

plt.savefig("../output_data/Fig8.png",dpi=100)
plt.show()
print(f"The correlation between Wind Speed (mph) and latitude is about {round(rvalue,2)}.")
# Out:
# The correlation between Wind Speed (mph) and latitude is about 0.0.

# %% [markdown]
# ### Three major findings:
# #### 1. There is a strong correlation between max tempurature and latitude;
# #### 2. There tends to be minimal relationship between humidity and latitude in South hemisphere. (r<0.1)
# #### 3. There is weak correlation between Cloudiness (%) and latitude.
